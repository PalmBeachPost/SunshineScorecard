# %%
from pyquery import PyQuery as pq
import requests
import re
import csv
from string import capwords
# import uucsv
from tabula import read_pdf
import pandas as pd
# Out:
# /anaconda3/lib/python3.6/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.23) or chardet (2.3.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
votelist = []    # to be billno, chamber, membername, vote, points
floorvotevalue = 3

# %%
billlist = []
#with open('billlist2.csv', newline='',encoding='utf-8-sig') as csvfile:
#moving things around to add MISSING AUTOVOTES (facepalm)
with open('HB7033.csv', newline='',encoding='utf-8-sig') as csvfile:
     reader = csv.DictReader(csvfile)
     for row in reader:
        if row['position'] == "bad":
            row['multiplier'] = -1
        elif row['position'] == "good":
            row['multiplier'] = 1
        else:
            print("Improper 'position' found for " + row['billno'] + ". What did you do?")
        billlist.append(row)

# %%
# html = requests.get("https://www.myfloridahouse.gov/Sections/Bills/floorvote.aspx?VoteId=17855&BillId=60058&SessionId=86&")
# yas = 
HEADERS = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10; rv:33.0) Gecko/20100101 Firefox/33.0'}

# %%
#this is just to add HB7033 floor votes
for row in billlist:
    position = row['position']
    billno = row['billno']
    sourceurl = row['url']
    print("Working on " + billno + ": " + sourceurl)
    multiplier = row['multiplier']            
    for lowchamber in ("house", "senate","house2"):
        if len(row[lowchamber]) > 0:   # If we have a valid URL
            chamber = capwords(lowchamber)
            print("Working on " + billno + " for the " + chamber)
            sourceurl = row[lowchamber]
            r = requests.get(sourceurl, headers=HEADERS)
            html = r.content 
            yeas = pq(html)("span#ctl00_MainContent_lblYeas").text().strip()
            nays = pq(html)("span#ctl00_MainContent_lblNays").text().strip()
            abstained = pq(html)("span#ctl00_MainContent_lblAbstained").text().strip()
            missed = pq(html)("span#ctl00_MainContent_lblMissed").text().strip()
            total = pq(html)("span#ctl00_MainContent_lblTotal").text().strip()
            ryeas = 0   # Start capturing real votes cast to compare.
            rnays = 0
            rsomething = 0
            rtotal = 0
            mainvotes = pq(html)("div.member-votes")
            for pol in pq(mainvotes)("li"):
                vote = pq(pq(pol)("span")[0]).text().strip()
                member = pq(pq(pol)("span")[1]).text().strip()
                # print(f"{vote}: {member}")
                points = 0
                if vote == "Y":
                    points = floorvotevalue * multiplier
                    ryeas += 1
                    rtotal += 1
                elif vote == "N":
                    points = floorvotevalue * multiplier * -1
                    rnays += 1
                    rtotal += 1
                else:
                    print(f"Vote {vote} found for {member} on {billno} in {chamber}")
                    # rtotal += 1   # Yes, No only counted toward total apparently
                    rsomething += 1
                entry = [billno, chamber, member, vote, str(points)]
                # print(member, vote, memberid)
                votelist.append(entry)
            if "Vote After Roll Call" in str(pq(html)):
                print("After-roll call votes need to be manually added for:\n\t"+ sourceurl)
            print(f"{yeas}-{nays}-{abstained}-{missed}-{total} votes from summary found. Y-N-A-M-Total")
            print(f"{ryeas}-{rnays}-{rsomething}-{rtotal} individual votes found Y-N-Something-Total")
# Out:
# Working on HB7033: https://www.myfloridahouse.gov/Sections/Bills/billsdetail.aspx?BillId=64895&SessionId=87
# Working on HB7033 for the House
# Vote - found for Avila on HB7033 in House
# Vote - found for Burton on HB7033 in House
# Vote - found for Maggard on HB7033 in House
# Vote - found for McClain on HB7033 in House
# Vote - found for Rodrigues, R. on HB7033 in House
# Vote - found for Sprowls on HB7033 in House
# Vote - found for Vacant on HB7033 in House
# Vote - found for Vacant on HB7033 in House
# After-roll call votes need to be manually added for:
# 	https://www.myfloridahouse.gov/Sections/Bills/floorvote.aspx?VoteId=18577&BillId=64895&SessionId=87&
# 112-0-0-8-112 votes from summary found. Y-N-A-M-Total
# 112-0-8-112 individual votes found Y-N-Something-Total
# Working on HB7033 for the Senate
# Vote - found for Lee on HB7033 in Senate
# Vote - found for Rader on HB7033 in Senate
# 38-0-0-2-38 votes from summary found. Y-N-A-M-Total
# 38-0-2-38 individual votes found Y-N-Something-Total

# %%
extracredits = []
for row in billlist:
    comvotelist = []
    position = row['position']
    billno = row['billno']
    sourceurl = row['url']
    print("Working on " + billno + ": " + sourceurl)
    multiplier = row['multiplier']
    r = requests.get(sourceurl, headers=HEADERS)
    html = r.content
    e = pq(html)
    for link in pq(html)('a').items():
        if "See Votes" in str(link.attr['title']):
            comvotelist.append('https://www.myfloridahouse.gov' + str(link.attr['href']))
    comlist = []
    for i in comvotelist:
        r = requests.get(i, headers=HEADERS)
        html = r.content 
        yeas = pq(html)("span#ctl00_MainContent_lblYeas").text().strip()
        nays = pq(html)("span#ctl00_MainContent_lblNays").text().strip()
        abstained = pq(html)("span#ctl00_MainContent_lblAbstained").text().strip()
        missed = pq(html)("span#ctl00_MainContent_lblMissed").text().strip()
        total = pq(html)("span#ctl00_MainContent_lblTotal").text().strip()
        ryeas = 0   # Start capturing real votes cast to compare.
        rnays = 0
        rsomething = 0
        rtotal = 0
        cmtename = pq(html)('span#ctl00_MainContent_lblCommittee').text().strip()
        mainvotes = pq(html)("div.committee-votes")
        for pol in pq(mainvotes)("li"):
            vote = pq(pq(pol)("span")[0]).text().strip()
            member = pq(pq(pol)("span")[1]).text().strip()
            # print(f"{vote}: {member}")
            points = 0
            if vote == "Y" or vote == "(Y)":
                points = floorvotevalue * multiplier
                votetype = "Committee Yes"
                vote = "Y"
                ryeas += 1
                rtotal += 1
            elif vote == "N":
                points = floorvotevalue * multiplier * -1
                votetype = "Committee No"
                rnays += 1
                rtotal += 1
            else:
                print(f"Vote {vote} found for {member} on {billno} in committee")
                # rtotal += 1   # Yes, No only counted toward total apparently
                rsomething += 1
                votetype = "Committee --"
                vote = "-"
            slug = billno + ": " +cmtename
            creditentry = [billno, 'House', member, votetype,\
                     str(points), position, vote, 'cmte vote',\
                    slug, cmtename, i, sourceurl]
            # print(member, vote, memberid)
            extracredits.append(creditentry)
        if "Vote After Roll Call" in str(pq(html)):
            print("After-roll call votes need to be manually added for COMMITTEE:\n\t"+ i)
    number = billno[2:]
    senateurl = 'https://www.flsenate.gov/Session/Bill/2019/' + str(number) + '/?Tab=VoteHistory'
    r = requests.get(senateurl, headers=HEADERS)
    html = r.content
    senvotelist = []
    e = pq(html)
    if 'No Committee Vote History Available' not in str(e):
        for link in e('div#tabBodyVoteHistory table.tbl').eq(0)('a').items():
            senvotelist.append('https://www.flsenate.gov'+str(link.attr['href']).replace(" ", "%20"))
    dflist = []
    for i in senvotelist:
        df = (read_pdf(i,lattice=True, area=(206.15, 21.69, 663.11, 317.63)))
        cmdf = read_pdf(i, guess=False, area=(58.26, 51.38, 72.77, 540),\
                pandas_options = {'header': None},\
                options="--columns 147.87")
        cmtename = cmdf[1][0]
        ryeas = 0   # Start capturing real votes cast to compare.
        rnays = 0
        rsomething = 0
        rtotal = 0
        x = 0
        slug = billno + ": " +cmtename
        foundyeas = df.iloc[-1]['Yea']
        foundnays = df.iloc[-1]['Nay']
        print('working on '+slug+": "+i)
        while x < len(df):
            senator = df['SENATORS'][x]
            if pd.isnull(senator) == False:
                if ',' in senator:
                    senator = re.split(',',senator)[0]
                if pd.isnull(df['Yea'][x]) == False:
                    points = floorvotevalue * multiplier
                    #votetype = "Committee Yes"
                    votetype = "Voted Yes"
                    vote = "Y"
                    ryeas += 1
                    rtotal += 1
                elif pd.isnull(df['Nay'][x]) == False:
                    points = floorvotevalue * multiplier * -1
                    #votetype = "Committee No"
                    votetype = "Voted No"
                    vote = "N"
                    rnays += 1
                    rtotal += 1
                else: 
                    rsomething +=1
                    print(f"Weird vote found for {senator} on {billno} in senate committee")
                    rsomething +=1
                    #votetype = "Committee --"
                    votetype = "Missed Vote"
                    vote = "-"
                    points = 0
                creditentry = [billno, 'Senate', senator, votetype,\
                     str(points), position, vote, 'cmte vote',\
                    slug, cmtename, i, sourceurl]
                # print(member, vote, memberid)
                extracredits.append(creditentry)
            x +=1
        if str(foundnays) != str(int(rnays)) or str(foundyeas) != str(int(ryeas)):
            print("Says off: Found "+str(ryeas)+" yeas and "+str(rnays)+ " nays. Doc says "+\
            str(foundyeas)+" yeas and "+str(foundnays)+" nays. See "+i)
                    
    
    for lowchamber in ("house", "senate","house2"):
        if len(row[lowchamber]) > 0:   # If we have a valid URL
            chamber = capwords(lowchamber)
            print("Working on " + billno + " for the " + chamber)
            sourceurl = row[lowchamber]
            r = requests.get(sourceurl, headers=HEADERS)
            html = r.content 
            yeas = pq(html)("span#ctl00_MainContent_lblYeas").text().strip()
            nays = pq(html)("span#ctl00_MainContent_lblNays").text().strip()
            abstained = pq(html)("span#ctl00_MainContent_lblAbstained").text().strip()
            missed = pq(html)("span#ctl00_MainContent_lblMissed").text().strip()
            total = pq(html)("span#ctl00_MainContent_lblTotal").text().strip()
            ryeas = 0   # Start capturing real votes cast to compare.
            rnays = 0
            rsomething = 0
            rtotal = 0
            mainvotes = pq(html)("div.member-votes")
            for pol in pq(mainvotes)("li"):
                vote = pq(pq(pol)("span")[0]).text().strip()
                member = pq(pq(pol)("span")[1]).text().strip()
                # print(f"{vote}: {member}")
                points = 0
                if vote == "Y":
                    points = floorvotevalue * multiplier
                    ryeas += 1
                    rtotal += 1
                elif vote == "N":
                    points = floorvotevalue * multiplier * -1
                    rnays += 1
                    rtotal += 1
                else:
                    print(f"Vote {vote} found for {member} on {billno} in {chamber}")
                    # rtotal += 1   # Yes, No only counted toward total apparently
                    rsomething += 1
                entry = [billno, chamber, member, vote, str(points)]
                # print(member, vote, memberid)
                votelist.append(entry)
            if "Vote After Roll Call" in str(pq(html)):
                print("After-roll call votes need to be manually added for:\n\t"+ sourceurl)
            print(f"{yeas}-{nays}-{abstained}-{missed}-{total} votes from summary found. Y-N-A-M-Total")
            print(f"{ryeas}-{rnays}-{rsomething}-{rtotal} individual votes found Y-N-Something-Total")
# Out:
# Working on HB7115: https://www.myfloridahouse.gov/Sections/Bills/billsdetail.aspx?BillId
://www.myfloridahouse.gov/Sections/Bills/floorvote.aspx?VoteId=18616&BillId=63056&SessionId=87&
# 116-0-0-4-116 votes from summary found. Y-N-A-M-Total
# 116-0-4-116 individual votes found Y-N-Something-Total
# Working on SB248 for the Senate
# 39-1-0-0-40 votes from summary found. Y-N-A-M-Total
# 39-1-0-40 individual votes found Y-N-Something-Total
# Working on HB7033: https://www.myfloridahouse.gov/Sections/Bills/billsdetail.aspx?BillId=64895&SessionId=87
# Vote - found for Daniels on HB7033 in committee
# Vote - found for DuBose on HB7033 in committee
# Vote - found for Clemons on HB7033 in committee
# Vote - found for Jacobs on HB7033 in committee
# Vote - found for McClain on HB7033 in committee
# Vote - found for Pigman on HB7033 in committee
# Vote - found for Slosberg on HB7033 in committee
# Working on HB7125: https://www.myfloridahouse.gov/Sections/Bills/billsdetail.aspx?BillId=66347&SessionId=87
# Vote - found for Jenne on HB7125 in committee
# Vote - found for Plasencia on HB7125 in committee
# Vote - found for Sprowls on HB7125 in committee
# Working on HB7125 for the House
# Vote - found for Hage on HB7125 in House
# Vote - found for Jacobs on HB7125 in House
# Vote - found for Jacquet on HB7125 in House
# Vote - found for Omphroy on HB7125 in House
# Vote - found for Roth on HB7125 in House
# Vote - found for Slosberg on HB7125 in House
# Vote - found for Vacant on HB7125 in House
# Vote - found for Vacant on HB7125 in House
# Vote - found for Vacant on HB7125 in House
# Vote - found for Watson, C. on HB7125 in House
# After-roll call votes need to be manually added for:
# 	https://www.myfloridahouse.gov/Sections/Bills/floorvote.aspx?VoteId=19152&BillId=66347&SessionId=87&
# 110-0-0-10-110 votes from summary found. Y-N-A-M-Total
# 110-0-10-110 individual votes found Y-N-Something-Total
# Working on HB7125 for the Senate
# 39-1-0-0-40 votes from summary found. Y-N-A-M-Total
# 39-1-0-40 individual votes found Y-N-Something-Total
# Working on HB7125 for the House2
# Vote - found for Fernandez-Barquin on HB7125 in House2
# Vote - found for Hogan Johnson on HB7125 in House2
# Vote - found for Jacobs on HB7125 in House2
# Vote - found for Jones on HB7125 in House2
# Vote - found for Vacant on HB7125 in House2
# Vote - found for Vacant on HB7125 in House2
# Vote - found for Vacant on HB7125 in House2
# After-roll call votes need to be manually added for:
# 	https://www.myfloridahouse.gov/Sections/Bills/floorvote.aspx?VoteId=18953&BillId=66347&SessionId=87&
# 112-1-0-7-113 votes from summary found. Y-N-A-M-Total
# 112-1-7-113 individual votes found Y-N-Something-Total

# %%
#commenting out so as to not mess anything up
#with open('extracredits2.csv', 'w', newline='') as csvfile:
    put = csv.writer(csvfile)
    header = ["billno", "chamber", "member", "vote", "points","good or bad bill?",\
             "Y or N","cmte vote","slug","cmte name","vote URL","main URL"]
    put.writerow(header)
    for entry in extracredits:
        put.writerow(entry)

# %%
#for actual use: replace autovotes_7033.csv with billlist2.csv
with open('autovotes_7033.csv', 'w', newline='') as csvfile:
    put = csv.writer(csvfile)
    header = ["billno", "chamber", "member", "vote", "points"]
    put.writerow(header)
    for entry in votelist:
        put.writerow(entry)
