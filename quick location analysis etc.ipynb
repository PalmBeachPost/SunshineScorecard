# %%
import pandas as pd

# %%
pols = pd.read_csv('pols2.csv')

# %%
auto = pd.read_csv('autovotes2.csv')
extraauto = pd.read_csv('extracredits2.csv')

# %%
df = pd.concat([auto,extraauto])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df.groupby('billno')['chamber'].count().sort_values(ascending=False)
# Out:
# billno
# HB7033    217
# HB7125    215
# SB248     193
# HB759     186
# HB407     180
# HB7124    120
# HB203      54
# HB7115     43
# SB7056     30
# SB1622     24
# SB602       6
# SB1416      6
# SB342       4
# SB1146      1
# SB1458      1
# SB186       1
# HB479       1
# HB265       1
# SB518       1
# HB1249      1
# HB1201      1
# Name: chamber, dtype: int64

# %%
report = pd.read_csv('report2.csv')

# %%
 df = pd.merge(pols, report, on="alphaname")

# %%
df.to_csv('joined_scores_details.csv',index=False)

# %%
locations = pd.read_csv('fldistricts2017.csv')

# %%
locations
# Out:
#      STATEFP  SLDLST  GEOID                  NAMELSAD LSAD   LSY  MTFCC  \
# 0         12       1  12001    State House District 1   LL  2016  G5220
# 1         12       2  12002    State House District 2   LL  2016  G5220
# 2         12       3  12003    State House District 3   LL  2016  G5220
# 3         12       4  12004    State House District 4   LL  2016  G5220
# 4         12       5  12005    State House District 5   LL  2016  G5220
# 5         12       6  12006    State House District 6   LL  2016  G5220
# 6         12       7  12007    State House District 7   LL  2016  G5220
# 7         12       8  12008    State House District 8   LL  2016  G5220
# 8         12       9  12009    State House District 9   LL  2016  G5220
# 9         12      10  12010   State House District 10   LL  2016  G5220
# 10        12      11  12011   State House District 11   LL  2016  G5220
# 11        12      12  12012   State House District 12   LL  2016  G5220
# ...
